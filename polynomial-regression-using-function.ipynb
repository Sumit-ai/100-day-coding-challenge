# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt 
sns.set()
x = [1,2,4,3,5, 6, 7, 8, 9, 10, 12, 13, 14, 15]
y = [1,2, 3, 4, 6, 7, 9, 10, 14, 18, 22, 28, 26, 32]
plt.plot(x,y, '*')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('X vs Y plot')
# Out:
# Text(0.5, 1.0, 'X vs Y plot')

# %%
# function for all the polynomial Regression
def polyfit(x, y, degree):
        import numpy
        results = {}

        coeffs = numpy.polyfit(x, y, degree)

         # Polynomial Coefficients
        results['polynomial'] = coeffs.tolist()

        # r-squared
        p = numpy.poly1d(coeffs)
        # fit values, and mean
        yhat = p(x)                         # or [p(z) for z in x]
        ybar = numpy.sum(y)/len(y)          # or sum(y)/len(y)
        ssreg = numpy.sum((yhat-ybar)**2)   # or sum([ (yihat - ybar)**2 for yihat in yhat])
        sstot = numpy.sum((y - ybar)**2)    # or sum([ (yi - ybar)**2 for yi in y])
        results['R square:'] = ssreg / sstot
        print('equation :')
        print( p)
        return p, results

# %% [markdown]
# # Linear Regression

# %%
p, results = polyfit(x,y, 1)
y_pred = p(x)

plt.plot(x,y, '*')
plt.plot(x,y_pred, '-o')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('X vs Y plot')
# Out:
# equation :
#
# 2.238 x - 4.423
# Text(0.5, 1.0, 'X vs Y plot')

# %% [markdown]
# # 2 degree polynomial regression

# %%
p, results = polyfit(x,y, 2)
y_pred = p(x)

plt.plot(x,y, '*')
plt.plot(x,y_pred, '-o')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('X vs Y plot')
# Out:
# equation :
#         2
# 0.1018 x + 0.597 x + 0.2138
# Text(0.5, 1.0, 'X vs Y plot')

# %% [markdown]
# # 3 degree polynomial regression

# %%
p, results = polyfit(x,y, 3)
y_pred = p(x)

plt.plot(x,y, '*')
plt.plot(x,y_pred, '-o')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('X vs Y plot')
# Out:
# equation :
#            3          2
# -0.006615 x + 0.2593 x - 0.4255 x + 1.764
# Text(0.5, 1.0, 'X vs Y plot')

# %% [markdown]
# # 4 degree polynomial regression

# %%
p, results = polyfit(x,y, 4)
y_pred = p(x)

plt.plot(x,y, '*')
plt.plot(x,y_pred, '-o')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('X vs Y plot')
# Out:
# equation :
#            4           3          2
# -0.001213 x + 0.03203 x - 0.1454 x + 1.121 x + 0.1769
# Text(0.5, 1.0, 'X vs Y plot')

# %% [markdown]
# # 5 degree polynomial regression

# %%
p, results = polyfit(x,y, 5)
y_pred = p(x)

plt.plot(x,y, '*')
plt.plot(x,y_pred, '-o')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('X vs Y plot')
# Out:
# equation :
#           5           4         3       2
# 0.000423 x - 0.01818 x + 0.278 x - 1.7 x + 5.159 x - 2.931
# Text(0.5, 1.0, 'X vs Y plot')
